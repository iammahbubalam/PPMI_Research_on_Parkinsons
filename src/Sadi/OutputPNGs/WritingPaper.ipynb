# %%
import pandas as pd

# %%
pd_one = pd.read_csv('/home/zagreus/Programming/PPMI_Research_on_Parkinsons/src/Sadi/NecessaryCSVFiles/MDS-UPDRS_Part_I_04Apr2024.csv')
pd_one_ques = pd.read_csv('/home/zagreus/Programming/PPMI_Research_on_Parkinsons/src/Sadi/NecessaryCSVFiles/MDS-UPDRS_Part_I_Patient_Questionnaire_04Apr2024.csv')
pd_two = pd.read_csv('/home/zagreus/Programming/PPMI_Research_on_Parkinsons/src/Sadi/NecessaryCSVFiles/MDS_UPDRS_Part_II__Patient_Questionnaire_04Apr2024.csv')
pd_three = pd.read_csv('/home/zagreus/Programming/PPMI_Research_on_Parkinsons/src/Sadi/NecessaryCSVFiles/MDS-UPDRS_Part_III_04Apr2024.csv')

# %%
pd_three
# Out:
#            REC_ID   PATNO EVENT_ID    PAG_NAME   INFODT  PDTRTMNT PDSTATE  \
# 0       272451901    3000       BL     NUPDRS3  02/2011       NaN     NaN
# 1       338703101    3000      V04     NUPDRS3  03/2012       NaN     NaN
# 2       385009801    3000      V06     NUPDRS3  02/2013       NaN     NaN
# 3       437131401    3000      V08     NUPDRS3  03/2014       NaN     NaN
# 4       512469901    3000      V10     NUPDRS3  03/2015       NaN     NaN
# ...           ...     ...      ...         ...      ...       ...     ...
# 26416  IANT457778  315720       BL  NUPDRDOSE3  04/2024       0.0     NaN
# 26417  IANT449915  315971       BL  NUPDRDOSE3  03/2024       0.0     NaN
# 26418  IANT448235  318884       BL  NUPDRDOSE3  03/2024       0.0     NaN
# 26419  IANT455515  319738       BL  NUPDRDOSE3  03/2024       0.0     NaN
# 26420  IANT446375  320596       BL  NUPDRDOSE3  03/2024       0.0     NaN
#
#        HRPOSTMED  HRDBSON  HRDBSOFF  ...  NP3RTARL  NP3RTALL  NP3RTALJ  \
# ...

# %%
pd_participants = pd.read_csv('/home/zagreus/Programming/PPMI_Research_on_Parkinsons/src/Sadi/NecessaryCSVFiles/Participant_Status_03Apr2024.csv')

# %%
pd_participants
# Out:
#        PATNO  COHORT    COHORT_DEFINITION ENROLL_DATE ENROLL_STATUS  \
# 0       3000       2      Healthy Control     02/2011      Enrolled
# 1       3001       1  Parkinson's Disease     03/2011      Enrolled
# 2       3002       1  Parkinson's Disease     03/2011      Enrolled
# 3       3003       1  Parkinson's Disease     04/2011      Enrolled
# 4       3004       2      Healthy Control     04/2011      Enrolled
# ...      ...     ...                  ...         ...           ...
# 4174  325051       1  Parkinson's Disease         NaN      Screened
# 4175  325566       1  Parkinson's Disease         NaN       Pending
# 4176  325718       1  Parkinson's Disease         NaN       Pending
# 4177  325723       2      Healthy Control         NaN      Screened
# 4178  329289       1  Parkinson's Disease         NaN       Pending
#
#      STATUS_DATE  ENROLL_AGE INEXPAGE  AV133STDY  TAUSTDY  ...  COMMENTS  \
# 0        05/2021        69.1   INEXHC        0.0      0.0  ...       NaN
# ...

# %%
pd_participants['CONCOHORT_DEFINITION'].value_counts()
# Out:
# CONCOHORT_DEFINITION
# Prodromal                                                      1233
# Parkinson's Disease                                            1227
# Healthy Control                                                 249
# non-PD, non-Prodromal, non-HC (participants to be excluded)      10
# SWEDD                                                             3
# Name: count, dtype: int64

# %%
print(pd_one['CONCOHORT'].value_counts())
print(pd_one_ques['CONCOHORT'].value_counts())
print(pd_two['CONCOHORT'].value_counts())
print(pd_three['CONCOHORT'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Programming/PPMI_Research_on_Parkinsons/venv/lib64/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CONCOHORT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ...

# %%
pd_ourdata = pd.read_csv('/home/zagreus/Programming/PPMI_Research_on_Parkinsons/src/Sadi/CreatingDataset/WorkingCSVs_DONT_DELETE/finalDatasetWithUPDRSScore.csv')

# %%
pd_ourdata['Patient ID'].value_counts()
# Out:
# Patient ID
# 3010      4
# 3661      4
# 3665      4
# 3666      4
# 3705      4
#          ..
# 3383      4
# 3385      4
# 3386      4
# 3387      4
# 142004    4
# Name: count, Length: 228, dtype: int64

# %%
master_dataset = pd.read_csv('/home/zagreus/Programming/PPMI_Research_on_Parkinsons/src/Sadi/CreatingDataset/WorkingCSVs_DONT_DELETE/finalDatasetWithUPDRSScore.csv')

# %%
master_dataset
# Out:
#      Patient ID Visit Date         Area  Circularity   ConvexArea  \
# 0          3010    2011-07   389.666667     0.347044   537.333333
# 1          3010    2012-06  1242.000000     0.232069  1594.333333
# 2          3010    2013-07   887.000000     0.521797  1025.000000
# 3          3010    2015-06   737.333333     0.175688   922.000000
# 4          3012    2011-10   862.333333     0.378363  1050.333333
# ..          ...        ...          ...          ...          ...
# 907      137450    2024-03   670.333333     0.119386  1239.000000
# 908      142004    2022-02   975.666667     0.441369  1238.000000
# 909      142004    2022-11  1286.333333     0.110355  2265.666667
# 910      142004    2023-04  1755.333333     0.305589  2503.666667
# 911      142004    2024-03   677.666667     0.270431   891.000000
#
#      EquivDiameter    Extent   FilledArea    Kurtosis  Major axis length  ...  \
# 0        21.855180  0.552101   393.333333  124.787788          27.661910  ...
# ...

# %%
master_dataset.columns
# Out:
# Index(['Patient ID', 'Visit Date', 'Area', 'Circularity', 'ConvexArea',
#        'EquivDiameter', 'Extent', 'FilledArea', 'Kurtosis',
#        'Major axis length', 'Mean', 'Minor axis length', 'PA_ratio',
#        'Shannon_Entropy', 'Skewness', 'Solidity', 'Standard Deviation',
#        'brightness', 'contrast', 'correlation', 'dissimilarity', 'energy',
#        'gabor_energy', 'gabor_entropy', 'homogeneity', 'lbp_energy',
#        'lbp_entropy', 'NP1ANXS', 'NP1APAT', 'NP1COG', 'NP1DDS', 'NP1DPRS',
#        'NP1HALL', 'NP1CNST', 'NP1FATG', 'NP1LTHD', 'NP1PAIN', 'NP1SLPD',
#        'NP1SLPN', 'NP1URIN', 'NP2DRES', 'NP2EAT', 'NP2FREZ', 'NP2HOBB',
#        'NP2HWRT', 'NP2HYGN', 'NP2RISE', 'NP2SALV', 'NP2SPCH', 'NP2SWAL',
#        'NP2TRMR', 'NP2TURN', 'NP2WALK', 'NP3BRADY', 'NP3FACXP', 'NP3FRZGT',
#        'NP3FTAPL', 'NP3FTAPR', 'NP3GAIT', 'NP3HMOVL', 'NP3HMOVR', 'NP3KTRML',
#        'NP3KTRMR', 'NP3LGAGL', 'NP3LGAGR', 'NP3POSTR', 'NP3PRSPL', 'NP3PRSPR',
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import RFE
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import mutual_info_classif
from skfeature.function.similarity_based import fisher_score

# %%
# Assuming df is your DataFrame and 'target' is your target column
X = master_dataset.drop(columns=['Patient ID', 'Visit Date', 'NHY', 'DATSCAN_CAUDATE_R', 'DATSCAN_CAUDATE_L', 'DATSCAN_PUTAMEN_R', 'DATSCAN_PUTAMEN_L', 'DATSCAN_PUTAMEN_R_ANT', 'DATSCAN_PUTAMEN_L_ANT', 'UPDRS_SCORE', 'Disease_Severity', 'Visit', 'Visit_int'])
y = master_dataset['Visit']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Random Forest Feature Importance
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_scaled, y)
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(12, 6))
plt.title('Random Forest Feature Importances')
plt.bar(range(X.shape[1]), importances[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Information Gain (Mutual Information)
mi = mutual_info_classif(X_scaled, y)

plt.figure(figsize=(12, 6))
plt.title('Information Gain (Mutual Information)')
plt.bar(range(X.shape[1]), mi[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Fisher Score
scores = fisher_score.fisher_score(X_scaled, y.values)

plt.figure(figsize=(12, 6))
plt.title('Fisher Score')
plt.bar(range(X.shape[1]), scores[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Recursive Feature Elimination (RFE)
model = LogisticRegression(max_iter=10000)
rfe = RFE(model, n_features_to_select=5)  # Adjust n_features_to_select as needed
rfe = rfe.fit(X_scaled, y)

plt.figure(figsize=(12, 6))
plt.title('RFE Feature Ranking')
plt.bar(range(X.shape[1]), rfe.ranking_[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# %%
# Assuming 'master_dataset' is your DataFrame and 'Visit' is the target column
X = master_dataset.drop(columns=['Patient ID', 'Visit Date', 'NHY', 'DATSCAN_CAUDATE_R',
                                 'DATSCAN_CAUDATE_L', 'DATSCAN_PUTAMEN_R', 'DATSCAN_PUTAMEN_L',
                                 'DATSCAN_PUTAMEN_R_ANT', 'DATSCAN_PUTAMEN_L_ANT', 'UPDRS_SCORE',
                                 'Disease_Severity', 'Visit', 'Visit_int'])
y = master_dataset['Visit']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Random Forest Feature Importance
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_scaled, y)
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

# Plot Random Forest Feature Importance
plt.figure(figsize=(12, 6))
plt.title('Random Forest Feature Importances')
plt.bar(range(X.shape[1]), importances[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Print top 20 features for Random Forest
print("Top 20 features by Random Forest importance:")
for i in range(20):
    print(f"{i+1}: {X.columns[indices[i]]}")

# Information Gain (Mutual Information)
mi = mutual_info_classif(X_scaled, y)

# Plot Information Gain
plt.figure(figsize=(12, 6))
plt.title('Information Gain (Mutual Information)')
plt.bar(range(X.shape[1]), mi[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Print top 20 features by Information Gain
print("Top 20 features by Information Gain:")
for i in range(20):
    print(f"{i+1}: {X.columns[indices[i]]}")

# Fisher Score
scores = fisher_score.fisher_score(X_scaled, y.values)

# Plot Fisher Score
plt.figure(figsize=(12, 6))
plt.title('Fisher Score')
plt.bar(range(X.shape[1]), scores[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Print top 20 features by Fisher Score
print("Top 20 features by Fisher Score:")
for i in range(20):
    print(f"{i+1}: {X.columns[indices[i]]}")

# Recursive Feature Elimination (RFE)
model = LogisticRegression(max_iter=10000)
rfe = RFE(model, n_features_to_select=5)  # Adjust n_features_to_select as needed
rfe = rfe.fit(X_scaled, y)

# Plot RFE Ranking
plt.figure(figsize=(12, 6))
plt.title('RFE Feature Ranking')
plt.bar(range(X.shape[1]), rfe.ranking_[indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Print top 20 features by RFE ranking
print("Top 20 features by RFE ranking:")
for i in range(20):
    print(f"{i+1}: {X.columns[indices[i]]}")
# Out:
# Top 20 features by Random Forest importance:
# 1: Circularity
# 2: Extent
# 3: Minor axis length
# 4: PA_ratio
# 5: Solidity
# 6: correlation
# 7: gabor_energy
# 8: Major axis length
# 9: energy
# 10: EquivDiameter
# 11: gabor_entropy
# 12: Standard Deviation
# 13: Mean
# 14: FilledArea
# 15: homogeneity
# 16: contrast
# 17: Area
# 18: ConvexArea
# 19: dissimilarity
# 20: Skewness
# Top 20 features by Information Gain:
# 1: Circularity
# 2: Extent
# 3: Minor axis length
# 4: PA_ratio
# 5: Solidity
# 6: correlation
# 7: gabor_energy
# 8: Major axis length
# 9: energy
# 10: EquivDiameter
# 11: gabor_entropy
# 12: Standard Deviation
# 13: Mean
# 14: FilledArea
# 15: homogeneity
# 16: contrast
# 17: Area
# 18: ConvexArea
# 19: dissimilarity
# 20: Skewness
# Top 20 features by Fisher Score:
# 1: Circularity
# 2: Extent
# 3: Minor axis length
# 4: PA_ratio
# 5: Solidity
# 6: correlation
# 7: gabor_energy
# 8: Major axis length
# 9: energy
# 10: EquivDiameter
# 11: gabor_entropy
# ...

# %%
# Assuming 'master_dataset' is your DataFrame and 'Visit' is the target column
X = master_dataset.drop(columns=['Patient ID', 'Visit Date', 'NHY', 'DATSCAN_CAUDATE_R',
                                 'DATSCAN_CAUDATE_L', 'DATSCAN_PUTAMEN_R', 'DATSCAN_PUTAMEN_L',
                                 'DATSCAN_PUTAMEN_R_ANT', 'DATSCAN_PUTAMEN_L_ANT', 'UPDRS_SCORE',
                                 'Disease_Severity', 'Visit', 'Visit_int'])
y = master_dataset['Visit']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Random Forest Feature Importance
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_scaled, y)
rf_importances = rf.feature_importances_
rf_indices = np.argsort(rf_importances)[::-1]

# Plot Random Forest Feature Importance
plt.figure(figsize=(12, 6))
plt.title('Random Forest Feature Importances')
plt.bar(range(X.shape[1]), rf_importances[rf_indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[rf_indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Print top 20 features for Random Forest
print("Top 20 features by Random Forest importance:")
for i in range(20):
    print(f"{i+1}: {X.columns[rf_indices[i]]}")

# Information Gain (Mutual Information)
mi_scores = mutual_info_classif(X_scaled, y)
mi_indices = np.argsort(mi_scores)[::-1]

# Plot Information Gain
plt.figure(figsize=(12, 6))
plt.title('Information Gain (Mutual Information)')
plt.bar(range(X.shape[1]), mi_scores[mi_indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[mi_indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Print top 20 features by Information Gain
print("Top 20 features by Information Gain:")
for i in range(20):
    print(f"{i+1}: {X.columns[mi_indices[i]]}")

# Fisher Score
fisher_scores = fisher_score.fisher_score(X_scaled, y.values)
fisher_indices = np.argsort(fisher_scores)[::-1]

# Plot Fisher Score
plt.figure(figsize=(12, 6))
plt.title('Fisher Score')
plt.bar(range(X.shape[1]), fisher_scores[fisher_indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[fisher_indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Print top 20 features by Fisher Score
print("Top 20 features by Fisher Score:")
for i in range(20):
    print(f"{i+1}: {X.columns[fisher_indices[i]]}")

# Recursive Feature Elimination (RFE)
model = LogisticRegression(max_iter=10000)
rfe = RFE(model, n_features_to_select=5)
rfe = rfe.fit(X_scaled, y)
rfe_ranking = rfe.ranking_
rfe_indices = np.argsort(rfe_ranking)

# Plot RFE Ranking
plt.figure(figsize=(12, 6))
plt.title('RFE Feature Ranking')
plt.bar(range(X.shape[1]), rfe_ranking[rfe_indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[rfe_indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Print top 20 features by RFE ranking
print("Top 20 features by RFE ranking (lower is better):")
for i in range(20):
    print(f"{i+1}: {X.columns[rfe_indices[i]]}")
# Out:
# Top 20 features by Random Forest importance:
# 1: Circularity
# 2: Extent
# 3: Minor axis length
# 4: PA_ratio
# 5: Solidity
# 6: correlation
# 7: gabor_energy
# 8: Major axis length
# 9: energy
# 10: EquivDiameter
# 11: gabor_entropy
# 12: Standard Deviation
# 13: Mean
# 14: FilledArea
# 15: homogeneity
# 16: contrast
# 17: Area
# 18: ConvexArea
# 19: dissimilarity
# 20: Skewness
# Top 20 features by Information Gain:
# 1: NP3FRZGT
# 2: NP2TURN
# 3: NP3PRSPR
# 4: NP3LGAGR
# 5: NP1SLPD
# 6: NP1SLPN
# 7: EquivDiameter
# 8: NP2SPCH
# 9: Major axis length
# 10: NP3RTALU
# 11: NP2RISE
# 12: NP3GAIT
# 13: NP1PAIN
# 14: NP3RTCON
# 15: NP2WALK
# 16: NP2SWAL
# 17: gabor_energy
# 18: Standard Deviation
# 19: NP3LGAGL
# 20: NP3BRADY
# Top 20 features by Fisher Score:
# 1: NP2WALK
# 2: NP2SWAL
# 3: NP3KTRMR
# 4: NP3POSTR
# 5: NP3SPCH
# 6: NP2TURN
# 7: contrast
# 8: NP3RIGRU
# 9: NP1DDS
# 10: NP3HMOVL
# 11: NP3RIGLL
# 12: NP3PRSPR
# 13: brightness
# 14: NP3RTALL
# 15: gabor_entropy
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, KBinsDiscretizer
from sklearn.feature_selection import chi2

# Assuming 'master_dataset' is your DataFrame and 'Visit' is the target column
master_dataset = pd.read_csv('/home/zagreus/Programming/PPMI_Research_on_Parkinsons/src/Sadi/CreatingDataset/WorkingCSVs_DONT_DELETE/finalDatasetWithUPDRSScore.csv')

X = master_dataset.drop(columns=['Patient ID', 'Visit Date', 'Area', 'Circularity', 'ConvexArea', 'EquivDiameter', 'Extent', 'FilledArea', 'Kurtosis', 'Major axis length', 'Mean', 'Minor axis length', 'PA_ratio', 'Shannon_Entropy', 'Skewness', 'Solidity', 'Standard Deviation', 'brightness', 'contrast', 'correlation', 'dissimilarity', 'energy', 'gabor_energy', 'gabor_entropy', 'homogeneity', 'lbp_energy', 'lbp_entropy', 'NHY', 'DATSCAN_CAUDATE_R', 'DATSCAN_CAUDATE_L', 'DATSCAN_PUTAMEN_R', 'DATSCAN_PUTAMEN_L','DATSCAN_PUTAMEN_R_ANT', 'DATSCAN_PUTAMEN_L_ANT', 'UPDRS_SCORE', 'Disease_Severity', 'Visit', 'Visit_int'])

y = master_dataset['Visit']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Discretize the features to make them categorical for Chi-Squared
discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
X_discretized = discretizer.fit_transform(X_scaled)

# Chi-Squared Test
chi2_scores, p_values = chi2(X_discretized, y)
chi2_indices = np.argsort(chi2_scores)[::-1]

print(len(X.columns))

# Plot Chi-Squared scores
plt.figure(figsize=(12, 6))
plt.title('Chi-Squared Test Feature Importance')
plt.bar(range(X.shape[1]), chi2_scores[chi2_indices], align='center')
plt.xticks(range(X.shape[1]), X.columns[chi2_indices], rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# Print top 20 features by Chi-Squared test
print("Top 20 features by Chi-Squared scores:")
for i in range(20):
    print(f"{i+1}: {X.columns[chi2_indices[i]]}")
# Out:
# 59
# Top 20 features by Chi-Squared scores:
# 1: NP2TURN
# 2: NP1CNST
# 3: NP1SLPD
# 4: NP2DRES
# 5: NP2EAT
# 6: NP1SLPN
# 7: NP2SPCH
# 8: NP2FREZ
# 9: NP3LGAGL
# 10: NP2RISE
# 11: NP2WALK
# 12: NP1URIN
# 13: NP3RIGLL
# 14: NP2HOBB
# 15: NP2SWAL
# 16: NP3PSTBL
# 17: NP3TTAPL
# 18: NP1DDS
# 19: NP2HWRT
# 20: NP1HALL

# %%
master_dataset = pd.read_csv('/home/zagreus/Programming/PPMI_Research_on_Parkinsons/src/Sadi/CreatingDataset/WorkingCSVs_DONT_DELETE/finalDatasetWithUPDRSScore.csv')

# Assuming 'master_dataset' is your DataFrame and 'Visit' is the target column
X = master_dataset.drop(columns=['Patient ID', 'Visit Date', 'Area', 'Circularity', 'ConvexArea', 'EquivDiameter', 'Extent', 'FilledArea', 'Kurtosis', 'Major axis length', 'Mean', 'Minor axis length', 'PA_ratio', 'Shannon_Entropy', 'Skewness', 'Solidity', 'Standard Deviation', 'brightness', 'contrast', 'correlation', 'dissimilarity', 'energy', 'gabor_energy', 'gabor_entropy', 'homogeneity', 'lbp_energy', 'lbp_entropy', 'NHY', 'DATSCAN_CAUDATE_R', 'DATSCAN_CAUDATE_L', 'DATSCAN_PUTAMEN_R', 'DATSCAN_PUTAMEN_L','DATSCAN_PUTAMEN_R_ANT', 'DATSCAN_PUTAMEN_L_ANT', 'UPDRS_SCORE', 'Disease_Severity', 'Visit', 'Visit_int'])

y = master_dataset['Visit']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Discretize the features to make them categorical for the Chi-Squared test
discretizer = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
X_discretized = discretizer.fit_transform(X_scaled)

# Chi-Squared Test
chi2_scores, p_values = chi2(X_discretized, y)
chi2_results = pd.DataFrame({'Feature': X.columns, 'Chi2 Score': chi2_scores, 'p-value': p_values})
chi2_results = chi2_results.sort_values(by='Chi2 Score', ascending=False)

# Plot Chi-Squared scores
plt.figure(figsize=(12, 6))
plt.title('Chi-Squared Test Feature Importance')
plt.barh(chi2_results['Feature'], chi2_results['Chi2 Score'], align='center')
plt.xlabel('Chi-Squared Score')
plt.ylabel('Features')
plt.gca().invert_yaxis()  # Reverse the y-axis to have the highest score on top
plt.show()

# Print the top 20 features by Chi-Squared test
print("Top 20 features by Chi-Squared test (with p-values):")
print(chi2_results.head(20))

# Check for features that are significant (p-value < 0.05)
significant_features = chi2_results[chi2_results['p-value'] < 0.05]
print("\nSignificant Features (p-value < 0.05):")
print(significant_features)
# Out:
# Top 20 features by Chi-Squared test (with p-values):
#      Feature  Chi2 Score       p-value
# 24   NP2TURN  137.266667  1.468164e-29
# 6    NP1CNST  108.515625  2.289633e-23
# 10   NP1SLPD   99.397004  2.094820e-21
# 13   NP2DRES   98.210526  3.769040e-21
# 14    NP2EAT   95.469767  1.463376e-20
# 11   NP1SLPN   87.438498  7.774046e-19
# 21   NP2SPCH   83.508197  5.424258e-18
# 15   NP2FREZ   80.682819  2.190610e-17
# 36  NP3LGAGL   74.255885  5.230941e-16
# 19   NP2RISE   73.252087  8.583677e-16
# 25   NP2WALK   72.694524  1.130137e-15
# 12   NP1URIN   70.538926  3.272294e-15
# 44  NP3RIGLL   69.557143  5.309866e-15
# 16   NP2HOBB   67.969336  1.161441e-14
# 22   NP2SWAL   64.947368  5.147755e-14
# 41  NP3PSTBL   60.363881  4.914758e-13
# 57  NP3TTAPL   59.806802  6.464292e-13
# 3     NP1DDS   59.800000  6.485958e-13
# 17   NP2HWRT   59.210299  8.668483e-13
# 5    NP1HALL   57.521739  1.988527e-12
#
# Significant Features (p-value < 0.05):
#      Feature  Chi2 Score       p-value
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file containing t-test results
# Assuming your CSV has columns like 'Feature', 'T-test Score', and 'p-value'
t_test_results = pd.read_csv('/home/zagreus/Programming/PPMI_Research_on_Parkinsons/src/Sadi/CreatingDataset/WorkingCSVs_DONT_DELETE/T_TestScoresCategorical.csv')

# Sort by T-test score (highest to lowest)
t_test_results = t_test_results.sort_values(by='V1 vs V2', ascending=False)

# Plot the top features by T-test score
plt.figure(figsize=(12, 6))
plt.title('T-Test Feature Importance')
plt.barh(t_test_results['Features'], t_test_results['V1 vs V2'], align='center')
plt.xlabel('T-Test Score')
plt.ylabel('Features')
plt.gca().invert_yaxis()  # Highest score on top
plt.show()

# Print top 20 features by T-test score
print("Top 20 features by T-Test Score:")
print(t_test_results.head(20))

# Check for significant features (if p-value column exists)
if 'p-value' in t_test_results.columns:
    significant_features = t_test_results[t_test_results['p-value'] < 0.05]
    print("\nSignificant Features (p-value < 0.05):")
    print(significant_features)
# Out:
# Top 20 features by T-Test Score:
#     Features  V1 vs V2  V1 vs V3  V1 vs V4  V2 vs V3  V2 vs V4  V3 vs V4
# 2     NP1COG  0.454783  0.098237  0.000005  0.110716  0.000004  0.000046
# 0    NP1ANXS  0.427197  0.108333  0.066468  0.080501  0.069726  0.001962
# 37  NP3LGAGR  0.390178  0.070567  0.000006  0.040771  0.000003  0.000622
# 43  NP3PTRMR  0.388269  0.350602  0.146794  0.459275  0.185829  0.207707
# 27  NP3FACXP  0.362255  0.500000  0.003904  0.347896  0.007621  0.003095
# 51  NP3RTALL  0.297041  0.211940  0.083144  0.373192  0.154135  0.254498
# 34  NP3KTRML  0.284974  0.117791  0.007724  0.200291  0.012845  0.067962
# 7    NP1FATG  0.239673  0.086320  0.000012  0.261512  0.000194  0.000962
# 50  NP3RTALJ  0.216987  0.282423  0.054382  0.097144  0.154135  0.002893
# 53  NP3RTARL  0.206138  0.044797  0.173449  0.104142  0.348510  0.266396
# 28  NP3FRZGT  0.159188  0.143017  0.008024  0.353169  0.044055  0.072391
# ...
